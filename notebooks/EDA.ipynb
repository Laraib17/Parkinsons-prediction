# %% [markdown]
# # Exploratory Data Analysis (EDA)
# In this notebook, we explore the Parkinson's disease dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
p_data = pd.read_csv('../data/parkinsons.csv') # Assuming data is in data folder
p_data.head()

# %%
p_data['status'].value_counts()

# %%
p_data.info()

# %%
p_data.describe()
